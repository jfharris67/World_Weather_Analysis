# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = coordinate = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
             
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description": city_desc})

        # YOUR CODE HERE
    
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | baruun-urt
# Processing Record 4 of Set 1 | apodi
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | brewster
# Processing Record 7 of Set 1 | rawson
# Processing Record 8 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | clyde river
# Processing Record 11 of Set 1 | faanui
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | beringovskiy
# Processing Record 18 of Set 1 | bambanglipuro
# Processing Record 19 of Set 1 | athabasca
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | pevek
# Processing Record 23 of Set 1 | caravelas
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | wadi maliz
# Processing Record 28 of Set 1 | faya
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | cap malheureux
# Processing Record 31 of Set 1 | klaksvik
# Processing Record 32 of Set 1 | kahului
# Processing Record 33 of Set 1 | lorengau
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | talnakh
# Processing Record 36 of Set 1 | sao filipe
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | victoria
# Processing Record 39 of Set 1 | kaeo
# Processing Record 40 of Set 1 | manggar
# Processing Record 41 of Set 1 | valleyview
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | tilichiki
# Processing Record 44 of Set 1 | pendleton
# Processing Record 45 of Set 1 | porto novo
# Processing Record 46 of Set 1 | pasinler
# Processing Record 47 of Set 1 | cidreira
# Processing Record 48 of Set 1 | jardim
# Processing Record 49 of Set 1 | poum
# Processing Record 50 of Set 1 | bocaranga
# City not found. Skipping...
# Processing Record 1 of Set 2 | rawatsar
# Processing Record 2 of Set 2 | tibiri
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | muzhi
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | akureyri
# Processing Record 10 of Set 2 | sampit
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | hamilton
# Processing Record 13 of Set 2 | wuda
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | severo-kurilsk
# Processing Record 18 of Set 2 | dutse
# Processing Record 19 of Set 2 | eluru
# Processing Record 20 of Set 2 | iquitos
# Processing Record 21 of Set 2 | placido de castro
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | chulym
# Processing Record 24 of Set 2 | chumikan
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | iqaluit
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | taiyuan
# Processing Record 29 of Set 2 | graham
# Processing Record 30 of Set 2 | vagur
# Processing Record 31 of Set 2 | comodoro rivadavia
# Processing Record 32 of Set 2 | ko samui
# Processing Record 33 of Set 2 | vanimo
# Processing Record 34 of Set 2 | yarke pole
# Processing Record 35 of Set 2 | la gaulette
# City not found. Skipping...
# Processing Record 36 of Set 2 | tessalit
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 2 | buala
# Processing Record 41 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | atuona
# Processing Record 44 of Set 2 | barcelona
# Processing Record 45 of Set 2 | requena
# Processing Record 46 of Set 2 | korla
# Processing Record 47 of Set 2 | tocopilla
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | bengkulu
# Processing Record 1 of Set 3 | sibolga
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | baoning
# Processing Record 4 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | pangai
# Processing Record 7 of Set 3 | nhulunbuy
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | pilar
# Processing Record 10 of Set 3 | xining
# Processing Record 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | walvis bay
# Processing Record 13 of Set 3 | lagoa
# Processing Record 14 of Set 3 | bosaso
# Processing Record 15 of Set 3 | nome
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | alice springs
# Processing Record 18 of Set 3 | vao
# Processing Record 19 of Set 3 | zolnoye
# City not found. Skipping...
# Processing Record 20 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 21 of Set 3 | kapaa
# Processing Record 22 of Set 3 | sangar
# Processing Record 23 of Set 3 | pisco
# Processing Record 24 of Set 3 | etchoropo
# Processing Record 25 of Set 3 | bathsheba
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | la ronge
# Processing Record 28 of Set 3 | ribeira grande
# Processing Record 29 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 3 | sioux lookout
# Processing Record 31 of Set 3 | te anau
# Processing Record 32 of Set 3 | christchurch
# Processing Record 33 of Set 3 | hualmay
# Processing Record 34 of Set 3 | xinpu
# Processing Record 35 of Set 3 | wanning
# Processing Record 36 of Set 3 | mahibadhoo
# Processing Record 37 of Set 3 | dong hoi
# Processing Record 38 of Set 3 | quatre cocos
# Processing Record 39 of Set 3 | sitka
# Processing Record 40 of Set 3 | barbastro
# Processing Record 41 of Set 3 | negombo
# Processing Record 42 of Set 3 | sainte-anne-des-monts
# Processing Record 43 of Set 3 | pathein
# Processing Record 44 of Set 3 | charagua
# Processing Record 45 of Set 3 | lavrentiya
# Processing Record 46 of Set 3 | barrow
# Processing Record 47 of Set 3 | gladstone
# Processing Record 48 of Set 3 | baryatino
# Processing Record 49 of Set 3 | luderitz
# Processing Record 50 of Set 3 | mar del plata
# Processing Record 1 of Set 4 | lata
# Processing Record 2 of Set 4 | saraland
# Processing Record 3 of Set 4 | port lincoln
# Processing Record 4 of Set 4 | kasamwa
# Processing Record 5 of Set 4 | ginda
# Processing Record 6 of Set 4 | piopio
# Processing Record 7 of Set 4 | orcopampa
# Processing Record 8 of Set 4 | samarai
# Processing Record 9 of Set 4 | srandakan
# Processing Record 10 of Set 4 | hofn
# Processing Record 11 of Set 4 | karatau
# Processing Record 12 of Set 4 | gazli
# Processing Record 13 of Set 4 | wana
# Processing Record 14 of Set 4 | tongliao
# Processing Record 15 of Set 4 | dikson
# Processing Record 16 of Set 4 | ambovombe
# Processing Record 17 of Set 4 | dali
# Processing Record 18 of Set 4 | hangu
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | isangel
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | cayenne
# Processing Record 23 of Set 4 | byron bay
# Processing Record 24 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 4 | batetskiy
# Processing Record 26 of Set 4 | samfya
# Processing Record 27 of Set 4 | kodiak
# Processing Record 28 of Set 4 | matai
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | namwala
# Processing Record 31 of Set 4 | kruisfontein
# Processing Record 32 of Set 4 | bubaque
# Processing Record 33 of Set 4 | saint george
# Processing Record 34 of Set 4 | uyuni
# Processing Record 35 of Set 4 | kabare
# Processing Record 36 of Set 4 | shubarkuduk
# Processing Record 37 of Set 4 | filadelfia
# Processing Record 38 of Set 4 | kupang
# Processing Record 39 of Set 4 | northam
# Processing Record 40 of Set 4 | cherskiy
# Processing Record 41 of Set 4 | yerbogachen
# Processing Record 42 of Set 4 | krasnoselkup
# Processing Record 43 of Set 4 | itupiranga
# Processing Record 44 of Set 4 | saldanha
# Processing Record 45 of Set 4 | lisburn
# Processing Record 46 of Set 4 | saint thomas
# Processing Record 47 of Set 4 | fairbanks
# Processing Record 48 of Set 4 | avera
# Processing Record 49 of Set 4 | strzegom
# Processing Record 50 of Set 4 | vardo
# Processing Record 1 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 5 | ilulissat
# Processing Record 3 of Set 5 | kollo
# Processing Record 4 of Set 5 | yar-sale
# Processing Record 5 of Set 5 | tahe
# Processing Record 6 of Set 5 | upernavik
# Processing Record 7 of Set 5 | vostok
# Processing Record 8 of Set 5 | coquimbo
# Processing Record 9 of Set 5 | broome
# Processing Record 10 of Set 5 | lookan
# Processing Record 11 of Set 5 | mocuba
# Processing Record 12 of Set 5 | paka
# Processing Record 13 of Set 5 | nove mesto na morave
# Processing Record 14 of Set 5 | mogadishu
# Processing Record 15 of Set 5 | lakatoro
# Processing Record 16 of Set 5 | russell
# Processing Record 17 of Set 5 | andi
# Processing Record 18 of Set 5 | limbang
# Processing Record 19 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 5 | puerto madryn
# Processing Record 21 of Set 5 | georgetown
# Processing Record 22 of Set 5 | santa cruz
# Processing Record 23 of Set 5 | coruripe
# Processing Record 24 of Set 5 | brekstad
# Processing Record 25 of Set 5 | urumqi
# Processing Record 26 of Set 5 | shimoda
# Processing Record 27 of Set 5 | lianran
# Processing Record 28 of Set 5 | honiara
# Processing Record 29 of Set 5 | barreirinhas
# Processing Record 30 of Set 5 | puerto penasco
# Processing Record 31 of Set 5 | andenes
# Processing Record 32 of Set 5 | thompson
# Processing Record 33 of Set 5 | sao jose da coroa grande
# Processing Record 34 of Set 5 | nikolskoye
# Processing Record 35 of Set 5 | tuy hoa
# Processing Record 36 of Set 5 | alta floresta
# Processing Record 37 of Set 5 | carnot
# Processing Record 38 of Set 5 | coihaique
# Processing Record 39 of Set 5 | grindavik
# Processing Record 40 of Set 5 | vila velha
# Processing Record 41 of Set 5 | miramar
# Processing Record 42 of Set 5 | karacabey
# Processing Record 43 of Set 5 | jalu
# Processing Record 44 of Set 5 | opuwo
# Processing Record 45 of Set 5 | mtwara
# Processing Record 46 of Set 5 | grand baie
# Processing Record 47 of Set 5 | mbanza-ngungu
# Processing Record 48 of Set 5 | aswan
# Processing Record 49 of Set 5 | prieska
# Processing Record 50 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 6 | sola
# Processing Record 2 of Set 6 | abu samrah
# Processing Record 3 of Set 6 | diu
# Processing Record 4 of Set 6 | leningradskiy
# Processing Record 5 of Set 6 | hami
# Processing Record 6 of Set 6 | carndonagh
# Processing Record 7 of Set 6 | ahipara
# Processing Record 8 of Set 6 | port hardy
# Processing Record 9 of Set 6 | aquiraz
# Processing Record 10 of Set 6 | laguna
# Processing Record 11 of Set 6 | langsa
# Processing Record 12 of Set 6 | rio gallegos
# Processing Record 13 of Set 6 | victor harbor
# Processing Record 14 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 6 | solnechnyy
# Processing Record 16 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 6 | westport
# Processing Record 18 of Set 6 | butaritari
# Processing Record 19 of Set 6 | pangnirtung
# Processing Record 20 of Set 6 | naze
# Processing Record 21 of Set 6 | avarua
# Processing Record 22 of Set 6 | turukhansk
# Processing Record 23 of Set 6 | kalmunai
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | prince rupert
# Processing Record 26 of Set 6 | roma
# Processing Record 27 of Set 6 | shingu
# Processing Record 28 of Set 6 | birjand
# Processing Record 29 of Set 6 | saint-augustin
# Processing Record 30 of Set 6 | nanchong
# Processing Record 31 of Set 6 | kulhudhuffushi
# Processing Record 32 of Set 6 | hasaki
# Processing Record 33 of Set 6 | kavieng
# Processing Record 34 of Set 6 | esperance
# Processing Record 35 of Set 6 | mount isa
# Processing Record 36 of Set 6 | riviere-au-renard
# Processing Record 37 of Set 6 | buchanan
# Processing Record 38 of Set 6 | yunyang
# Processing Record 39 of Set 6 | touros
# Processing Record 40 of Set 6 | nambucca heads
# Processing Record 41 of Set 6 | manokwari
# Processing Record 42 of Set 6 | egvekinot
# Processing Record 43 of Set 6 | salalah
# Processing Record 44 of Set 6 | anori
# Processing Record 45 of Set 6 | pochutla
# Processing Record 46 of Set 6 | ostrovnoy
# Processing Record 47 of Set 6 | berdigestyakh
# Processing Record 48 of Set 6 | cordoba
# Processing Record 49 of Set 6 | khingansk
# Processing Record 50 of Set 6 | juneau
# Processing Record 1 of Set 7 | san quintin
# Processing Record 2 of Set 7 | haines junction
# Processing Record 3 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 7 | mantua
# Processing Record 5 of Set 7 | torbay
# Processing Record 6 of Set 7 | katsuura
# Processing Record 7 of Set 7 | zabid
# Processing Record 8 of Set 7 | tabat
# Processing Record 9 of Set 7 | takoradi
# Processing Record 10 of Set 7 | george
# Processing Record 11 of Set 7 | santa fe
# Processing Record 12 of Set 7 | harper
# Processing Record 13 of Set 7 | benghazi
# Processing Record 14 of Set 7 | geraldton
# Processing Record 15 of Set 7 | holme
# Processing Record 16 of Set 7 | rafai
# Processing Record 17 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 7 | wanlaweyn
# Processing Record 19 of Set 7 | coahuayana
# Processing Record 20 of Set 7 | souillac
# Processing Record 21 of Set 7 | gboko
# Processing Record 22 of Set 7 | sacramento
# Processing Record 23 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 7 | saint-ambroise
# Processing Record 25 of Set 7 | estepa
# Processing Record 26 of Set 7 | margate
# Processing Record 27 of Set 7 | rio grande
# Processing Record 28 of Set 7 | chuy
# Processing Record 29 of Set 7 | den helder
# Processing Record 30 of Set 7 | arman
# Processing Record 31 of Set 7 | tvoroyri
# Processing Record 32 of Set 7 | gaogou
# Processing Record 33 of Set 7 | tuatapere
# Processing Record 34 of Set 7 | mayumba
# Processing Record 35 of Set 7 | bull savanna
# Processing Record 36 of Set 7 | pratapgarh
# Processing Record 37 of Set 7 | zorritos
# Processing Record 38 of Set 7 | codrington
# Processing Record 39 of Set 7 | saint-denis
# Processing Record 40 of Set 7 | ancud
# Processing Record 41 of Set 7 | bodden town
# Processing Record 42 of Set 7 | atar
# Processing Record 43 of Set 7 | armash
# Processing Record 44 of Set 7 | bilibino
# Processing Record 45 of Set 7 | matara
# Processing Record 46 of Set 7 | kavaratti
# Processing Record 47 of Set 7 | kenai
# Processing Record 48 of Set 7 | ust-nera
# Processing Record 49 of Set 7 | parthenay
# Processing Record 50 of Set 7 | ejura
# Processing Record 1 of Set 8 | banda aceh
# Processing Record 2 of Set 8 | verkh-chebula
# Processing Record 3 of Set 8 | eyl
# Processing Record 4 of Set 8 | nargana
# Processing Record 5 of Set 8 | mungeli
# Processing Record 6 of Set 8 | virginia beach
# Processing Record 7 of Set 8 | axim
# Processing Record 8 of Set 8 | steenwijk
# Processing Record 9 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 8 | iberia
# Processing Record 11 of Set 8 | port antonio
# Processing Record 12 of Set 8 | cootamundra
# Processing Record 13 of Set 8 | tiznit
# Processing Record 14 of Set 8 | mapiripan
# Processing Record 15 of Set 8 | pontes e lacerda
# Processing Record 16 of Set 8 | abiy adi
# City not found. Skipping...
# Processing Record 17 of Set 8 | gilgit
# Processing Record 18 of Set 8 | matrei
# City not found. Skipping...
# Processing Record 19 of Set 8 | olafsvik
# Processing Record 20 of Set 8 | canyon lake
# Processing Record 21 of Set 8 | thunder bay
# Processing Record 22 of Set 8 | xicotencatl
# Processing Record 23 of Set 8 | mallapuram
# Processing Record 24 of Set 8 | necochea
# Processing Record 25 of Set 8 | vestmannaeyjar
# Processing Record 26 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 8 | arawa
# Processing Record 28 of Set 8 | narsaq
# Processing Record 29 of Set 8 | kingisepp
# Processing Record 30 of Set 8 | san cristobal
# Processing Record 31 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 8 | nagato
# Processing Record 33 of Set 8 | kozhevnikovo
# Processing Record 34 of Set 8 | porto velho
# Processing Record 35 of Set 8 | masuguru
# Processing Record 36 of Set 8 | pitimbu
# Processing Record 37 of Set 8 | ayan
# Processing Record 38 of Set 8 | myre
# Processing Record 39 of Set 8 | deputatskiy
# Processing Record 40 of Set 8 | tautira
# Processing Record 41 of Set 8 | nanortalik
# Processing Record 42 of Set 8 | barnala
# Processing Record 43 of Set 8 | plettenberg bay
# Processing Record 44 of Set 8 | utinga
# Processing Record 45 of Set 8 | tunja
# Processing Record 46 of Set 8 | ulaanbaatar
# Processing Record 47 of Set 8 | riyadh
# Processing Record 48 of Set 8 | auki
# Processing Record 49 of Set 8 | norman
# Processing Record 50 of Set 8 | seymchan
# Processing Record 1 of Set 9 | wanaka
# Processing Record 2 of Set 9 | lyambir
# Processing Record 3 of Set 9 | vallenar
# Processing Record 4 of Set 9 | jiquipilas
# Processing Record 5 of Set 9 | moron
# Processing Record 6 of Set 9 | asyut
# Processing Record 7 of Set 9 | roald
# Processing Record 8 of Set 9 | nizwa
# Processing Record 9 of Set 9 | port elizabeth
# Processing Record 10 of Set 9 | solano
# Processing Record 11 of Set 9 | batemans bay
# Processing Record 12 of Set 9 | belo jardim
# Processing Record 13 of Set 9 | mayo
# Processing Record 14 of Set 9 | khani
# Processing Record 15 of Set 9 | cockburn town
# Processing Record 16 of Set 9 | lawton
# Processing Record 17 of Set 9 | aden
# Processing Record 18 of Set 9 | mana
# Processing Record 19 of Set 9 | clarence town
# Processing Record 20 of Set 9 | bereda
# Processing Record 21 of Set 9 | longyearbyen
# Processing Record 22 of Set 9 | saskylakh
# Processing Record 23 of Set 9 | denpasar
# Processing Record 24 of Set 9 | fortuna
# Processing Record 25 of Set 9 | bachaquero
# Processing Record 26 of Set 9 | sargatskoye
# Processing Record 27 of Set 9 | soc trang
# Processing Record 28 of Set 9 | envira
# Processing Record 29 of Set 9 | charlestown
# Processing Record 30 of Set 9 | richards bay
# Processing Record 31 of Set 9 | bilma
# Processing Record 32 of Set 9 | vrangel
# Processing Record 33 of Set 9 | riberalta
# Processing Record 34 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 35 of Set 9 | bambous virieux
# Processing Record 36 of Set 9 | changli
# Processing Record 37 of Set 9 | jaisalmer
# Processing Record 38 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 39 of Set 9 | tipitapa
# Processing Record 40 of Set 9 | puerto escondido
# Processing Record 41 of Set 9 | san matias
# Processing Record 42 of Set 9 | mehamn
# Processing Record 43 of Set 9 | pala
# Processing Record 44 of Set 9 | lamar
# Processing Record 45 of Set 9 | beloha
# Processing Record 46 of Set 9 | abha
# Processing Record 47 of Set 9 | pachino
# Processing Record 48 of Set 9 | kavarna
# Processing Record 49 of Set 9 | agva
# City not found. Skipping...
# Processing Record 50 of Set 9 | kurbnesh
# Processing Record 1 of Set 10 | luganville
# Processing Record 2 of Set 10 | araouane
# Processing Record 3 of Set 10 | luwuk
# Processing Record 4 of Set 10 | hays
# Processing Record 5 of Set 10 | buritis
# Processing Record 6 of Set 10 | toledo
# Processing Record 7 of Set 10 | krasnozerskoye
# Processing Record 8 of Set 10 | anadyr
# Processing Record 9 of Set 10 | challans
# Processing Record 10 of Set 10 | san policarpo
# Processing Record 11 of Set 10 | zhezkazgan
# Processing Record 12 of Set 10 | meulaboh
# Processing Record 13 of Set 10 | awbari
# Processing Record 14 of Set 10 | shache
# Processing Record 15 of Set 10 | jiazi
# Processing Record 16 of Set 10 | huilong
# Processing Record 17 of Set 10 | flinders
# Processing Record 18 of Set 10 | tera
# Processing Record 19 of Set 10 | londa
# Processing Record 20 of Set 10 | fethiye
# Processing Record 21 of Set 10 | lincoln
# Processing Record 22 of Set 10 | mount gambier
# Processing Record 23 of Set 10 | xiamen
# Processing Record 24 of Set 10 | nkayi
# Processing Record 25 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 10 | mitsamiouli
# Processing Record 27 of Set 10 | dryden
# Processing Record 28 of Set 10 | senador pompeu
# Processing Record 29 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 10 | panguna
# Processing Record 31 of Set 10 | aklavik
# Processing Record 32 of Set 10 | berlevag
# Processing Record 33 of Set 10 | springdale
# Processing Record 34 of Set 10 | hovd
# Processing Record 35 of Set 10 | pokhara
# Processing Record 36 of Set 10 | linjiang
# Processing Record 37 of Set 10 | taltal
# Processing Record 38 of Set 10 | salo
# Processing Record 39 of Set 10 | evensk
# Processing Record 40 of Set 10 | baghmara
# Processing Record 41 of Set 10 | garissa
# Processing Record 42 of Set 10 | yandyki
# Processing Record 43 of Set 10 | asfi
# Processing Record 44 of Set 10 | miri
# Processing Record 45 of Set 10 | ust-kuyga
# Processing Record 46 of Set 10 | poya
# Processing Record 47 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 10 | hanmer springs
# Processing Record 49 of Set 10 | sorland
# Processing Record 50 of Set 10 | ellisras
# Processing Record 1 of Set 11 | ostersund
# Processing Record 2 of Set 11 | nuevo progreso
# Processing Record 3 of Set 11 | portland
# Processing Record 4 of Set 11 | vanavara
# Processing Record 5 of Set 11 | ziarat
# Processing Record 6 of Set 11 | carnarvon
# Processing Record 7 of Set 11 | jasper
# Processing Record 8 of Set 11 | norman wells
# Processing Record 9 of Set 11 | monforte de lemos
# Processing Record 10 of Set 11 | ausa
# Processing Record 11 of Set 11 | iwanai
# Processing Record 12 of Set 11 | kendari
# Processing Record 13 of Set 11 | mackay
# Processing Record 14 of Set 11 | high level
# Processing Record 15 of Set 11 | lake city
# Processing Record 16 of Set 11 | maningrida
# Processing Record 17 of Set 11 | payo
# Processing Record 18 of Set 11 | basqal
# Processing Record 19 of Set 11 | springfield
# Processing Record 20 of Set 11 | dzaoudzi
# Processing Record 21 of Set 11 | nyurba
# Processing Record 22 of Set 11 | gilbues
# Processing Record 23 of Set 11 | doha
# Processing Record 24 of Set 11 | kloulklubed
# Processing Record 25 of Set 11 | lingen
# Processing Record 26 of Set 11 | palmer
# Processing Record 27 of Set 11 | katrineholm
# Processing Record 28 of Set 11 | constitucion
# Processing Record 29 of Set 11 | kutum
# Processing Record 30 of Set 11 | huai yot
# Processing Record 31 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 11 | bayan
# Processing Record 33 of Set 11 | salym
# Processing Record 34 of Set 11 | los llanos de aridane
# Processing Record 35 of Set 11 | agadir
# Processing Record 36 of Set 11 | harlingen
# Processing Record 37 of Set 11 | brazzaville
# Processing Record 38 of Set 11 | bhatgaon
# Processing Record 39 of Set 11 | birnin kebbi
# Processing Record 40 of Set 11 | chizhou
# Processing Record 41 of Set 11 | hirara
# Processing Record 42 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 43 of Set 11 | unai
# Processing Record 44 of Set 11 | xuddur
# Processing Record 45 of Set 11 | binzhou
# Processing Record 46 of Set 11 | vila franca do campo
# Processing Record 47 of Set 11 | manta
# Processing Record 48 of Set 11 | hun
# Processing Record 49 of Set 11 | ossora
# Processing Record 50 of Set 11 | duz
# City not found. Skipping...
# Processing Record 1 of Set 12 | nova olimpia
# Processing Record 2 of Set 12 | havoysund
# Processing Record 3 of Set 12 | shasta lake
# Processing Record 4 of Set 12 | paamiut
# Processing Record 5 of Set 12 | kamaishi
# Processing Record 6 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 12 | sechelt
# Processing Record 8 of Set 12 | mecca
# Processing Record 9 of Set 12 | tual
# Processing Record 10 of Set 12 | durham
# Processing Record 11 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 12 | port macquarie
# Processing Record 13 of Set 12 | novobureyskiy
# Processing Record 14 of Set 12 | atbasar
# Processing Record 15 of Set 12 | katobu
# Processing Record 16 of Set 12 | dunedin
# Processing Record 17 of Set 12 | barguzin
# Processing Record 18 of Set 12 | komsomolskiy
# Processing Record 19 of Set 12 | inirida
# Processing Record 20 of Set 12 | ugrinovci
# Processing Record 21 of Set 12 | qasigiannguit
# Processing Record 22 of Set 12 | mezen
# Processing Record 23 of Set 12 | contai
# Processing Record 24 of Set 12 | gopalpur
# Processing Record 25 of Set 12 | santiago
# Processing Record 26 of Set 12 | barinas
# Processing Record 27 of Set 12 | cabras
# Processing Record 28 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 29 of Set 12 | skibotn
# Processing Record 30 of Set 12 | udachnyy
# Processing Record 31 of Set 12 | uray
# Processing Record 32 of Set 12 | sinjar
# Processing Record 33 of Set 12 | kribi
# Processing Record 34 of Set 12 | kysyl-syr
# Processing Record 35 of Set 12 | srednekolymsk
# Processing Record 36 of Set 12 | naryan-mar
# Processing Record 37 of Set 12 | bajina basta
# Processing Record 38 of Set 12 | chardara
# Processing Record 39 of Set 12 | sulya
# Processing Record 40 of Set 12 | zalantun
# Processing Record 41 of Set 12 | nizhniy kuranakh
# Processing Record 42 of Set 12 | ketchikan
# Processing Record 43 of Set 12 | taoudenni
# Processing Record 44 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 12 | lasa
# Processing Record 46 of Set 12 | sao joao da barra
# Processing Record 47 of Set 12 | yeppoon
# Processing Record 48 of Set 12 | syasstroy
# Processing Record 49 of Set 12 | sisimiut
# Processing Record 50 of Set 12 | kiruna
# Processing Record 1 of Set 13 | redlands
# Processing Record 2 of Set 13 | chiali
# City not found. Skipping...
# Processing Record 3 of Set 13 | sorkjosen
# Processing Record 4 of Set 13 | khaga
# Processing Record 5 of Set 13 | sadao
# Processing Record 6 of Set 13 | mpongwe
# Processing Record 7 of Set 13 | maceio
# Processing Record 8 of Set 13 | primorsko
# Processing Record 9 of Set 13 | flin flon
# Processing Record 10 of Set 13 | port moresby
# Processing Record 11 of Set 13 | krasnogorsk
# Processing Record 12 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 13 of Set 13 | borovoy
# Processing Record 14 of Set 13 | ankang
# Processing Record 15 of Set 13 | cabra
# Processing Record 16 of Set 13 | krasnorechenskiy
# Processing Record 17 of Set 13 | paredon
# Processing Record 18 of Set 13 | anda
# Processing Record 19 of Set 13 | abbeville
# Processing Record 20 of Set 13 | bantry
# Processing Record 21 of Set 13 | ndele
# Processing Record 22 of Set 13 | puerto leguizamo
# Processing Record 23 of Set 13 | ovsyanka
# Processing Record 24 of Set 13 | bundaberg
# Processing Record 25 of Set 13 | altamont
# Processing Record 26 of Set 13 | sinnamary
# Processing Record 27 of Set 13 | mosquera
# Processing Record 28 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 29 of Set 13 | la asuncion
# Processing Record 30 of Set 13 | alekseyevsk
# Processing Record 31 of Set 13 | boddam
# Processing Record 32 of Set 13 | coihueco
# Processing Record 33 of Set 13 | ziro
# Processing Record 34 of Set 13 | rabo de peixe
# Processing Record 35 of Set 13 | bulgan
# Processing Record 36 of Set 13 | niamey
# Processing Record 37 of Set 13 | arthur
# Processing Record 38 of Set 13 | glubokoe
# City not found. Skipping...
# Processing Record 39 of Set 13 | itarema
# Processing Record 40 of Set 13 | padang
# Processing Record 41 of Set 13 | fairhope
# Processing Record 42 of Set 13 | dingle
# Processing Record 43 of Set 13 | kirakira
# Processing Record 44 of Set 13 | lloydminster
# Processing Record 45 of Set 13 | bangkalan
# Processing Record 46 of Set 13 | qaqortoq
# Processing Record 47 of Set 13 | praya
# Processing Record 48 of Set 13 | hay river
# Processing Record 49 of Set 13 | dalbandin
# Processing Record 50 of Set 13 | wasilla
# Processing Record 1 of Set 14 | tigil
# Processing Record 2 of Set 14 | muros
# Processing Record 3 of Set 14 | san ramon
# Processing Record 4 of Set 14 | husavik
# Processing Record 5 of Set 14 | puerto ayacucho
# Processing Record 6 of Set 14 | birin
# Processing Record 7 of Set 14 | seidu
# Processing Record 8 of Set 14 | yinchuan
# Processing Record 9 of Set 14 | moussoro
# Processing Record 10 of Set 14 | celina
# Processing Record 11 of Set 14 | little chute
# Processing Record 12 of Set 14 | yamada
# Processing Record 13 of Set 14 | ugoofaaru
# Processing Record 14 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 14 | druzhba
# Processing Record 16 of Set 14 | lompoc
# Processing Record 17 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 18 of Set 14 | santa isabel do rio negro
# Processing Record 19 of Set 14 | gorgan
# Processing Record 20 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 14 | malakal
# Processing Record 22 of Set 14 | kitaibaraki
# Processing Record 23 of Set 14 | sambava
# Processing Record 24 of Set 14 | darhan
# Processing Record 25 of Set 14 | morristown
# Processing Record 26 of Set 14 | miraflores
# Processing Record 27 of Set 14 | scalea
# Processing Record 28 of Set 14 | moranbah
# Processing Record 29 of Set 14 | oistins
# Processing Record 30 of Set 14 | agadez
# Processing Record 31 of Set 14 | okhotsk
# Processing Record 32 of Set 14 | lazaro cardenas
# Processing Record 33 of Set 14 | carutapera
# Processing Record 34 of Set 14 | kushima
# Processing Record 35 of Set 14 | cozumel
# Processing Record 36 of Set 14 | bluefield
# Processing Record 37 of Set 14 | miyako
# Processing Record 38 of Set 14 | seryshevo
# Processing Record 39 of Set 14 | tagusao
# Processing Record 40 of Set 14 | ocos
# Processing Record 41 of Set 14 | nacogdoches
# Processing Record 42 of Set 14 | kundiawa
# Processing Record 43 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 44 of Set 14 | majene
# Processing Record 45 of Set 14 | yulara
# Processing Record 46 of Set 14 | keti bandar
# Processing Record 47 of Set 14 | maua
# Processing Record 48 of Set 14 | hudiksvall
# Processing Record 49 of Set 14 | yarada
# Processing Record 50 of Set 14 | formosa
# Processing Record 1 of Set 15 | monroe
# Processing Record 2 of Set 15 | godda
# Processing Record 3 of Set 15 | nuevitas
# Processing Record 4 of Set 15 | vestmanna
# Processing Record 5 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 6 of Set 15 | deulgaon raja
# Processing Record 7 of Set 15 | aksu
# Processing Record 8 of Set 15 | mount pleasant
# Processing Record 9 of Set 15 | bafilo
# Processing Record 10 of Set 15 | cururupu
# Processing Record 11 of Set 15 | saint-louis
# Processing Record 12 of Set 15 | conway
# Processing Record 13 of Set 15 | yumen
# Processing Record 14 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 15 of Set 15 | keelung
# Processing Record 16 of Set 15 | omboue
# Processing Record 17 of Set 15 | tura
# Processing Record 18 of Set 15 | duvan
# Processing Record 19 of Set 15 | ochakiv
# Processing Record 20 of Set 15 | desbiens
# Processing Record 21 of Set 15 | martapura
# Processing Record 22 of Set 15 | adrar
# Processing Record 23 of Set 15 | kazanlak
# Processing Record 24 of Set 15 | upata
# Processing Record 25 of Set 15 | villa union
# Processing Record 26 of Set 15 | thinadhoo
# Processing Record 27 of Set 15 | soltsy
# Processing Record 28 of Set 15 | igarka
# Processing Record 29 of Set 15 | star
# Processing Record 30 of Set 15 | umtata
# Processing Record 31 of Set 15 | uvat
# Processing Record 32 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 33 of Set 15 | kljajicevo
# Processing Record 34 of Set 15 | kieta
# Processing Record 35 of Set 15 | namibe
# Processing Record 36 of Set 15 | kearney
# Processing Record 37 of Set 15 | phnum penh
# City not found. Skipping...
# Processing Record 38 of Set 15 | lere
# Processing Record 39 of Set 15 | cairns
# Processing Record 40 of Set 15 | namatanai
# Processing Record 41 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 15 | luau
# Processing Record 43 of Set 15 | bandar penggaram
# City not found. Skipping...
# Processing Record 44 of Set 15 | marrakesh
# Processing Record 45 of Set 15 | kawalu
# Processing Record 46 of Set 15 | saint-francois
# Processing Record 47 of Set 15 | ankara
# Processing Record 48 of Set 15 | chara
# Processing Record 49 of Set 15 | sao gabriel da cachoeira
# Processing Record 50 of Set 15 | krasnomayskiy
# Processing Record 1 of Set 16 | marsa matruh
# Processing Record 2 of Set 16 | tiarei
# Processing Record 3 of Set 16 | finschhafen
# Processing Record 4 of Set 16 | nanton
# Processing Record 5 of Set 16 | bloomington
# Processing Record 6 of Set 16 | ardmore
# Processing Record 7 of Set 16 | yuli
# Processing Record 8 of Set 16 | mildura
# Processing Record 9 of Set 16 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 16 | trincomalee
# Processing Record 11 of Set 16 | caucaia
# Processing Record 12 of Set 16 | norden
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 705

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany  42.6001  -73.9662     43.74        94         100
# 1        Bethel  41.3712  -73.4140     54.03        86         100
# 2    Baruun-Urt  46.6806  113.2792    -14.73        84          54
# 3         Apodi  -5.6642  -37.7989     92.05        36           3
# 4  Puerto Ayora  -0.7393  -90.3518     73.54        95          98
# 5      Brewster  41.3973  -73.6171     54.68        94         100
# 6        Rawson -43.3002  -65.1023     73.67        37           3
# 7   Tuktoyaktuk  69.4541 -133.0374     -9.44        78         100
# 8   Clyde River  70.4692  -68.5914    -10.97        70          20
# 9        Faanui -16.4833 -151.7500     81.03        77         100
#
#    Wind Speed Country Current Description
# 0        4.65      US          light rain
# 1        8.05      US     overcast clouds
# 2        4.14      MN       broken clouds
# 3        8.28      BR           clear sky
# 4        7.00      EC     overcast clouds
# 5        8.05      US     overcast clouds
# 6        4.29      AR           clear sky
# 7       12.33      CA     overcast clouds
# 8        5.75      CA          few clouds
# 9       25.55      PF          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)

# Display sample data
# YOUR CODE HERE
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.6001  -73.9662     43.74        94         100
# 1        Bethel      US  41.3712  -73.4140     54.03        86         100
# 2    Baruun-Urt      MN  46.6806  113.2792    -14.73        84          54
# 3         Apodi      BR  -5.6642  -37.7989     92.05        36           3
# 4  Puerto Ayora      EC  -0.7393  -90.3518     73.54        95          98
# 5      Brewster      US  41.3973  -73.6171     54.68        94         100
# 6        Rawson      AR -43.3002  -65.1023     73.67        37           3
# 7   Tuktoyaktuk      CA  69.4541 -133.0374     -9.44        78         100
# 8   Clyde River      CA  70.4692  -68.5914    -10.97        70          20
# 9        Faanui      PF -16.4833 -151.7500     81.03        77         100
#
#    Wind Speed Current Description
# 0        4.65          light rain
# 1        8.05     overcast clouds
# 2        4.14       broken clouds
# 3        8.28           clear sky
# 4        7.00     overcast clouds
# 5        8.05     overcast clouds
# 6        4.29           clear sky
# 7       12.33     overcast clouds
# 8        5.75          few clouds
# 9       25.55          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
